# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

video_df = pd.read_csv('video.csv')
X = video_df.drop(columns='content')
y = video_df['content']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
prediction = model.predict(X_test)
score = accuracy_score(y_test, prediction)
score
# Out:
# 0.5

# %%
video_df
# Out:
#     age  gender                     content
# 0    18       1                      gaming
# 1    20       1                      gaming
# 2    23       1     Education and Tutorials
# 3    25       1     Education and Tutorials
# 4    26       1  Tech Reviews and Unboxings
# 5    29       1  Tech Reviews and Unboxings
# 6    30       1                       Vlogs
# 7    31       1     Science and Exploration
# 8    33       1     science and Exploration
# 9    35       1          Fitness and Health
# 10   40       1         News and Commentary
# 11   18       0         Comedy and Sketches
# 12   20       0         Comedy and Sketches
# 13   21       0          Beauty and Fashion
# 14   23       0          Beauty and Fashion
# 15   25       0   Product Reviews and Hauls
# 16   26       0            Food and Cooking
# 17   27       0            Food and Cooking
# 18   30       0    Lifestyle and Motivation
# 19   31       0                        ASMR
# 20   34       0                        ASMR
